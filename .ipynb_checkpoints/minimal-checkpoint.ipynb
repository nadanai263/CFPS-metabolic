# %%
# Simulate the Python model

from scipy.integrate import odeint
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import tellurium as te

# %%
run parsemodel.py
# Out:
# ['atp', 'adp', 'nad', 'nadh', 'ppi', 'pppi', 'pep', 'pyr', 'm', 'P', 'Pmat']
# [ 2.    0.    0.25  0.   25.    0.   33.    0.    0.    0.    0.  ]
# ['VmaxPyk', 'Keq11', 'Kadp11', 'Kpep11', 'Katp11', 'Kpyr11', 'VmaxPpase', 'Keq22', 'Kpppi22', 'Kppi22', 'VmaxNoxe', 'Knadh23', 'Vmaxtx', 'd', 'KTX', 'Katp', 'kdeg', 'Vmaxtl', 'KTL', 'kmat', 'Vmax']
# [1.0, 5000.0, 0.3, 0.3, 1.0, 1.0, 20.0, 10.0, 0.1, 0.1, 1.0, 0.1, 2e-05, 1e-06, 1e-05, 1.0, 0.0001, 2e-06, 0.0001, 0.0005, 1.0]
#
# v_J11 = VmaxPyk*(pep*adp-pyr*atp/Keq11)/(Kadp11*Kpep11)*1/((1+adp/Kadp11)*(1+pep/Kpep11)+(1+atp/Katp11)*(1+pyr/Kpyr11)-1)
# v_J22 = VmaxPpase*(pppi-ppi*ppi/Keq22)/Kpppi22*1/(1+pppi/Kpppi22+(1+ppi/Kppi22)*(1+ppi/Kppi22)-1)
# v_J23 = VmaxNoxe*nadh/(Knadh23+nadh)
# v_Jdegpep = 0.001*pep
# v_JTX = Vmaxtx*d/(d+KTX)*atp/(atp+Katp)
# v_Jdeg = kdeg*m
# v_JTL = Vmaxtl*m/(m+KTL)*atp/(atp+Katp)
# v_JMat = kmat*P
#
# datp/dt = 3.0*v_J11 - 170.0*v_JTX - 904.0*v_JTL
# dadp/dt = -3.0*v_J11 + 170.0*v_JTX + 904.0*v_JTL
# dnad/dt = 4.0*v_J23
# dnadh/dt = -4.0*v_J23
# dppi/dt = 4.0*v_J22 + v_Jdegpep + 170.0*v_JTX + 904.0*v_JTL
# dpppi/dt = -2.0*v_J22
# dpep/dt = -3.0*v_J11 - v_Jdegpep
# dpyr/dt = 3.0*v_J11
# dm/dt = v_JTX - v_Jdeg
# dP/dt = v_JTL - v_JMat
# dPmat/dt = v_JMat

# %%
import model_Korman.minimal as Korman
PATH_TO_OUTPUT = "./modeloutput/"
FILENAME = "korman.csv"

# Do not use dict as ordering is not guaranteed. Use list instead.
y0 = np.array(Korman.valuesVar)
params = np.array(Korman.valuesPar)
TMAX = 20000 # s
NSTEPS = 10000

time = np.linspace(0,TMAX,NSTEPS)
sol = odeint(Korman.model, y0, time, args=(params,),atol=1e-12) # Scipy solver

# Plot and save plot
for i in range(sol.shape[1]):
    plt.plot(time,sol[:,i], label=Korman.keysVar[i]);
plt.xlabel('t (s)'); plt.ylabel('concs (mM)'); plt.legend()   
#plt.savefig(PATH_TO_OUTPUT+'plot.pdf',transparent=True)
plt.show() 

# Save data
#df = pd.DataFrame(sol)
#df.to_csv(PATH_TO_OUTPUT+FILENAME, index=None)

# %%
# conservation of mass
atp = sol[:,0]
adp = sol[:,1]
nad = sol[:,2]
nadh = sol[:,3]

ppi = sol[:,4]
pppi = sol[:,5]

pep = sol[:,6]
pyr = sol[:,7]

    
carbon = 3*pep+3*pyr
plt.plot(carbon)

# %%
phosphate = 3*atp+2*adp+pep+2*pppi+ppi
plt.plot(phosphate)

# %%
# Plot and save plot

sel = [8,10]
for i in sel:
    plt.plot(time,sol[:,i], label=Korman.keysVar[i]);
plt.xlabel('t (s)'); plt.ylabel('concs (mM)'); plt.legend()   
#plt.savefig(PATH_TO_OUTPUT+'plotCOF.pdf',transparent=True)
plt.show()

# %%
# Plot and save plot

sel = [0,1]
for i in sel:
    plt.plot(time,sol[:,i], label=Korman.keysVar[i]);
plt.xlabel('t (s)'); plt.ylabel('concs (mM)'); plt.legend()   
#plt.savefig(PATH_TO_OUTPUT+'plotCOF.pdf',transparent=True)
plt.show()
